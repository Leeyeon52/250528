# %%
import numpy as np
import pandas as pd
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
pd.options.display.max_colwidth = 80
pd.options.display.max_columns = 20
np.random.seed(2023)
np.set_printoptions(precision=4, suppress=True)
import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=(8, 4))

# %%
# ai hub
# https://aihub.or.kr/aihubdata/data/list.do?pageIndex=1&currMenu=&topMenu=&dataSetSn=&srchdataClCode=DATACL001&searchKeyword=%EC%97%AC%ED%96%89&srchDetailCnd=DETAILCND001&srchOrder=ORDER001&srchPagePer=20

# %%
# !wget -q https://raw.githubusercontent.com/kairess/toy-datasets/master/tn_travel_%E1%84%8B%E1%85%A7%E1%84%92%E1%85%A2%E1%86%BC_A.csv
# !wget -q https://raw.githubusercontent.com/kairess/toy-datasets/master/tn_traveller_master_%E1%84%8B%E1%85%A7%E1%84%92%E1%85%A2%E1%86%BC%E1%84%80%E1%85%A2%E1%86%A8%20Master_A.csv
# !wget -q https://raw.githubusercontent.com/kairess/toy-datasets/master/tn_visit_area_info_%E1%84%87%E1%85%A1%E1%86%BC%E1%84%86%E1%85%AE%E1%86%AB%E1%84%8C%E1%85%B5%E1%84%8C%E1%85%A5%E1%86%BC%E1%84%87%E1%85%A9_A.csv
# Out:
# 'wget'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'wget'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'wget'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# 데이터셋 로드
df_place = pd.read_csv(r'D:\학습\250528\제주및도서지역\tn_visit_area_info_방문지정보.csv')
df_place.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18588\2691325732.py:2: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_place = pd.read_csv(r'D:\학습\250528\제주및도서지역\tn_visit_area_info_방문지정보.csv')
#    VISIT_AREA_ID  TRAVEL_ID  VISIT_ORDER VISIT_AREA_NM VISIT_START_YMD  \
# 0     2210210002  d_d006731            7         미스틱3도      2022-10-21
# 1     2210180004  d_d002613            3       에스제이렌트카      2022-10-18
# 2     2209030004  d_d001011           20         루프탑정원      2022-09-03
# 3     2209170005  d_d001386           17          법환식당      2022-09-17
# 4     2210090001  d_d002308           16       돌카롱 중문점      2022-10-09
#
#   VISIT_END_YMD               ROAD_NM_ADDR               LOTNO_ADDR  \
# 0    2022-10-21  제주특별자치도 제주시 1100로 2894-49   제주특별자치도 제주시 노형동 291-10
# 1    2022-10-18      제주특별자치도 제주시 오일장중길 100  제주특별자치도 제주시 도두일동 1286-1
# 2    2022-09-03                        NaN                      NaN
# 3    2022-09-17     제주특별자치도 서귀포시 이어도로 1046   제주특별자치도 서귀포시 서호동 128-7
# 4    2022-10-09     제주특별자치도 서귀포시 중문로41번길 8  제주특별자치도 서귀포시 중문동 1588-1
#
#       X_COORD    Y_COORD  ...       POI_NM RESIDENCE_TIME_MIN  \
# 0  126.487556  33.449947  ...  신비원(석부작돌공원)               60.0
# 1  126.477007  33.498441  ...        푸조렌트카               30.0
# 2  126.745408   33.28386  ...          NaN               60.0
# 3  126.522849  33.245022  ...          NaN               30.0
# 4  126.424303  33.255724  ...          NaN               30.0
#
#   VISIT_AREA_TYPE_CD REVISIT_YN  VISIT_CHC_REASON_CD  LODGING_TYPE_CD DGSTFN  \
# 0                 13          N                  2.0              NaN    5.0
# 1                 10          N                  2.0              NaN    4.0
# 2                 24          N                  2.0              7.0    2.0
# 3                 11          N                  9.0              NaN    5.0
# 4                 11          N                  2.0              NaN    4.0
#
#    REVISIT_INTENTION  RCMDTN_INTENTION   SGG_CD
# 0                5.0               5.0      NaN
# 1                4.0               4.0      NaN
# 2                1.0               2.0  50130.0
# 3                4.0               5.0      NaN
# 4                4.0               4.0      NaN
#
# [5 rows x 23 columns]

# %%
df_travel = pd.read_csv(r'D:\학습\250528\제주및도서지역\tn_travel_여행.csv')
df_travel.head()
# Out:
#    TRAVEL_ID TRAVEL_NM TRAVELER_ID   TRAVEL_PURPOSE TRAVEL_START_YMD  \
# 0  b_b010312       D02     b010312   1;21;22;24;27;       2022-10-29
# 1  b_b005266       D02     b005266  21;22;23;24;26;       2022-10-12
# 2  d_d000296       D01     d000296               2;       2022-08-18
# 3  d_d002565       D01     d002565           22;23;       2022-10-29
# 4  d_d006390       D01     d006390      2;22;4;5;6;       2022-10-15
#
#   TRAVEL_END_YMD MVMN_NM   TRAVEL_PERSONA   TRAVEL_MISSION  \
# 0     2022-10-31  대중교통 등              NaN   1;21;22;24;27;
# 1     2022-10-14     자가용              NaN  21;22;23;24;26;
# 2     2022-08-22  대중교통 등  40세 이상 자녀 동반 여행               2;
# 3     2022-11-01     자가용              NaN           22;23;
# 4     2022-10-19  대중교통 등  39세 이하 3인 이상 친구      2;22;4;5;6;
#
#   TRAVEL_MISSION_CHECK
# 0             21;22;26
# 1              12;22;3
# 2              2;28;12
# 3              22;23;2
# 4               5;22;6

# %%
df_travel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3200 entries, 0 to 3199
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TRAVEL_ID             3200 non-null   object
#  1   TRAVEL_NM             3200 non-null   object
#  2   TRAVELER_ID           3200 non-null   object
#  3   TRAVEL_PURPOSE        3200 non-null   object
#  4   TRAVEL_START_YMD      3200 non-null   object
#  5   TRAVEL_END_YMD        3200 non-null   object
#  6   MVMN_NM               3063 non-null   object
#  7   TRAVEL_PERSONA        870 non-null    object
#  8   TRAVEL_MISSION        3200 non-null   object
#  9   TRAVEL_MISSION_CHECK  3200 non-null   object
# dtypes: object(10)
# memory usage: 250.1+ KB

# %%
df_traveler = pd.read_csv(r'D:\학습\250528\제주및도서지역\tn_traveller_master_여행객 Master.csv')
df_traveler.head()
# Out:
#   TRAVELER_ID  RESIDENCE_SGG_CD GENDER  AGE_GRP  EDU_NM  EDU_FNSH_SE  \
# 0     b011774                31      여       30       6            1
# 1     d009928                29      여       20       6            2
# 2     d010131                26      남       20       7            2
# 3     d006004                50      여       20       6            1
# 4     d002965                50      여       30       6            1
#
#    MARR_STTS  FAMILY_MEMB  JOB_NM  JOB_ETC  ...  TRAVEL_STYL_7  TRAVEL_STYL_8  \
# 0          1            1     3.0      NaN  ...              2              6
# 1          1            4    12.0      NaN  ...              1              7
# 2          1            1    12.0      NaN  ...              2              7
# 3          1            1     3.0      NaN  ...              3              6
# 4          2            4     3.0      NaN  ...              1              4
#
#    TRAVEL_STATUS_RESIDENCE  TRAVEL_STATUS_DESTINATION  \
# 0                    울산광역시                         경남
# 1                    광주광역시                         제주
# 2                    부산광역시                         제주
# 3                  제주특별자치도                         제주
# 4                  제주특별자치도                         제주
#
#    TRAVEL_STATUS_ACCOMPANY      TRAVEL_STATUS_YMD  TRAVEL_MOTIVE_1  \
# 0                 2인 가족 여행  2022-10-25~2022-10-26                2
# 1              2인 여행(가족 외)  2022-10-30~2022-11-01                2
# 2                   나홀로 여행  2022-11-02~2022-11-04                5
# 3              2인 여행(가족 외)  2022-10-30~2022-10-31                3
# 4                 자녀 동반 여행  2022-10-08~2022-10-10                3
#
#    TRAVEL_MOTIVE_2  TRAVEL_MOTIVE_3  TRAVEL_COMPANIONS_NUM
# 0              1.0              5.0                      1
# 1              1.0              5.0                      1
# 2              2.0             10.0                      0
# 3              1.0              7.0                      1
# 4              1.0              8.0                      3
#
# [5 rows x 36 columns]

# %%
# 데이터 병합
df = pd.merge(df_place, df_travel, on='TRAVEL_ID', how='left')
df = pd.merge(df, df_traveler, on='TRAVELER_ID', how='left')
df.head()
# Out:
#    VISIT_AREA_ID  TRAVEL_ID  VISIT_ORDER VISIT_AREA_NM VISIT_START_YMD  \
# 0     2210210002  d_d006731            7         미스틱3도      2022-10-21
# 1     2210180004  d_d002613            3       에스제이렌트카      2022-10-18
# 2     2209030004  d_d001011           20         루프탑정원      2022-09-03
# 3     2209170005  d_d001386           17          법환식당      2022-09-17
# 4     2210090001  d_d002308           16       돌카롱 중문점      2022-10-09
#
#   VISIT_END_YMD               ROAD_NM_ADDR               LOTNO_ADDR  \
# 0    2022-10-21  제주특별자치도 제주시 1100로 2894-49   제주특별자치도 제주시 노형동 291-10
# 1    2022-10-18      제주특별자치도 제주시 오일장중길 100  제주특별자치도 제주시 도두일동 1286-1
# 2    2022-09-03                        NaN                      NaN
# 3    2022-09-17     제주특별자치도 서귀포시 이어도로 1046   제주특별자치도 서귀포시 서호동 128-7
# 4    2022-10-09     제주특별자치도 서귀포시 중문로41번길 8  제주특별자치도 서귀포시 중문동 1588-1
#
#       X_COORD    Y_COORD  ...  TRAVEL_STYL_7 TRAVEL_STYL_8  \
# 0  126.487556  33.449947  ...            2.0           7.0
# 1  126.477007  33.498441  ...            1.0           6.0
# 2  126.745408   33.28386  ...            NaN           NaN
# 3  126.522849  33.245022  ...            2.0           3.0
# 4  126.424303  33.255724  ...            NaN           NaN
#
#   TRAVEL_STATUS_RESIDENCE TRAVEL_STATUS_DESTINATION  TRAVEL_STATUS_ACCOMPANY  \
# 0                   서울특별시                        제주          3대 동반 여행(친척 포함)
# 1                    전라북도                        제주              2인 여행(가족 외)
# 2                     NaN                       NaN                      NaN
# 3                     강원도                        제주           3인 이상 여행(가족 외)
# 4                     NaN                       NaN                      NaN
#
#        TRAVEL_STATUS_YMD TRAVEL_MOTIVE_1  TRAVEL_MOTIVE_2  TRAVEL_MOTIVE_3  \
# 0  2022-10-20~2022-10-24             3.0              7.0             10.0
# 1  2022-10-16~2022-10-18             3.0              1.0              7.0
# 2                    NaN             NaN              NaN              NaN
# 3  2022-09-16~2022-09-18             1.0              3.0              7.0
# 4                    NaN             NaN              NaN              NaN
#
#    TRAVEL_COMPANIONS_NUM
# 0                    3.0
# 1                    1.0
# 2                    NaN
# 3                    3.0
# 4                    NaN
#
# [5 rows x 67 columns]

# %%
print(df['TRAVEL_ID'].unique())
# Out:
# ['d_d006731' 'd_d002613' 'd_d001011' ... 'd_d005988' 'a_a007289'
#  'c_c000241']

# %%
df[df['TRAVEL_ID'] == 'd_d006731']
# Out:
#        VISIT_AREA_ID  TRAVEL_ID  VISIT_ORDER VISIT_AREA_NM VISIT_START_YMD  \
# 0         2210210002  d_d006731            7         미스틱3도      2022-10-21
# 2126      2210200002  d_d006731            4      이호테우해수욕장      2022-10-20
# 2581      2210210003  d_d006731            8       털보네장원랜드      2022-10-21
# 3749      2210200004  d_d006731            2    김포국제공항 국내선      2022-10-20
# 5730      2210240003  d_d006731           23        제주국제공항      2022-10-24
# ...              ...        ...          ...           ...             ...
# 49038     2210240004  d_d006731           24    김포국제공항 국내선      2022-10-24
# 56179     2210230005  d_d006731           20           덴드리      2022-10-23
# 56926     2210230001  d_d006731           16           송악산      2022-10-23
# 60480     2210220004  d_d006731           15            수월      2022-10-22
# 60506     2210210001  d_d006731            6    항파두리 항몽유적지      2022-10-21
#
#       VISIT_END_YMD                 ROAD_NM_ADDR                   LOTNO_ADDR  \
# 0        2022-10-21    제주특별자치도 제주시 1100로 2894-49       제주특별자치도 제주시 노형동 291-10
# 2126     2022-10-20                          NaN     제주특별자치도 제주시 이호일동 1665-13
# 2581     2022-10-21                          NaN                          NaN
# 3749     2022-10-20               서울 강서구 하늘길 112              서울 강서구 공항동 1373
# 5730     2022-10-24            제주특별자치도 제주시 공항로 2        제주특별자치도 제주시 용담2동 2002
# ...             ...                          ...                          ...
# 49038    2022-10-24               서울 강서구 하늘길 112              서울 강서구 공항동 1373
# 56179    2022-10-23    제주특별자치도 서귀포시 성산읍 삼달로 28-1  제주특별자치도 서귀포시 성산읍 삼달리 115-11
# 56926    2022-10-23                          NaN     제주특별자치도 서귀포시 대정읍 상모리 산 2
# 60480    2022-10-23  제주특별자치도 서귀포시 대정읍 추사로38번길 96  제주특별자치도 서귀포시 대정읍 안성리 1785-3
# 60506    2022-10-21     제주특별자치도 제주시 애월읍 항파두리로 50     제주특별자치도 제주시 애월읍 상귀리 1012
#
#            X_COORD      Y_COORD  ...  TRAVEL_STYL_7 TRAVEL_STYL_8  \
# 0       126.487556    33.449947  ...            2.0           7.0
# 2126    126.452691    33.497377  ...            2.0           7.0
# 2581           NaN          NaN  ...            2.0           7.0
# 3749    126.802865    37.558949  ...            2.0           7.0
# 5730    126.492769    33.507079  ...            2.0           7.0
# ...            ...          ...  ...            ...           ...
# 49038  126.8028655  37.55894903  ...            2.0           7.0
# 56179  126.8660544  33.36958969  ...            2.0           7.0
# 56926  126.2897914  33.19908294  ...            2.0           7.0
# 60480  126.2791497  33.25817943  ...            2.0           7.0
# 60506  126.4079226  33.45274787  ...            2.0           7.0
#
#       TRAVEL_STATUS_RESIDENCE TRAVEL_STATUS_DESTINATION  \
# 0                       서울특별시                        제주
# 2126                    서울특별시                        제주
# 2581                    서울특별시                        제주
# 3749                    서울특별시                        제주
# 5730                    서울특별시                        제주
# ...                       ...                       ...
# 49038                   서울특별시                        제주
# 56179                   서울특별시                        제주
# 56926                   서울특별시                        제주
# 60480                   서울특별시                        제주
# 60506                   서울특별시                        제주
#
#        TRAVEL_STATUS_ACCOMPANY      TRAVEL_STATUS_YMD TRAVEL_MOTIVE_1  \
# 0              3대 동반 여행(친척 포함)  2022-10-20~2022-10-24             3.0
# 2126           3대 동반 여행(친척 포함)  2022-10-20~2022-10-24             3.0
# 2581           3대 동반 여행(친척 포함)  2022-10-20~2022-10-24             3.0
# 3749           3대 동반 여행(친척 포함)  2022-10-20~2022-10-24             3.0
# 5730           3대 동반 여행(친척 포함)  2022-10-20~2022-10-24             3.0
# ...                        ...                    ...             ...
# 49038          3대 동반 여행(친척 포함)  2022-10-20~2022-10-24             3.0
# 56179          3대 동반 여행(친척 포함)  2022-10-20~2022-10-24             3.0
# 56926          3대 동반 여행(친척 포함)  2022-10-20~2022-10-24             3.0
# 60480          3대 동반 여행(친척 포함)  2022-10-20~2022-10-24             3.0
# 60506          3대 동반 여행(친척 포함)  2022-10-20~2022-10-24             3.0
#
#        TRAVEL_MOTIVE_2  TRAVEL_MOTIVE_3  TRAVEL_COMPANIONS_NUM
# 0                  7.0             10.0                    3.0
# 2126               7.0             10.0                    3.0
# 2581               7.0             10.0                    3.0
# 3749               7.0             10.0                    3.0
# 5730               7.0             10.0                    3.0
# ...                ...              ...                    ...
# 49038              7.0             10.0                    3.0
# 56179              7.0             10.0                    3.0
# 56926              7.0             10.0                    3.0
# 60480              7.0             10.0                    3.0
# 60506              7.0             10.0                    3.0
#
# [22 rows x 67 columns]

# %%
# 전처리 1
df_fil = df[~df['TRAVEL_MISSION_CHECK'].isnull()].copy()
df_fil.loc[:, 'TRAVEL_MISSION_INT'] = df_fil['TRAVEL_MISSION_CHECK'].str.split(';').str[0].astype(int)
df_fil #23898 rows × 68 columns
# Out:
#        VISIT_AREA_ID  TRAVEL_ID  VISIT_ORDER  VISIT_AREA_NM VISIT_START_YMD  \
# 0         2210210002  d_d006731            7          미스틱3도      2022-10-21
# 1         2210180004  d_d002613            3        에스제이렌트카      2022-10-18
# 3         2209170005  d_d001386           17           법환식당      2022-09-17
# 4         2210090001  d_d002308           16        돌카롱 중문점      2022-10-09
# 6         2210310002  d_d009541            7         에코랜드호텔      2022-10-31
# ...              ...        ...          ...            ...             ...
# 62266     2209270001  d_d001473           12     문개항아리 조천본점      2022-09-27
# 62267     2208220008  d_d000761            8     머큐어앰배서더 제주      2022-08-22
# 62269     2210030006  d_d001455           22        메종글래드제주      2022-10-03
# 62270     2209100002  a_a002144            8  옹진농협하나로마트 덕적점      2022-09-10
# 62271     2210210006  d_d005392            2     김포국제공항 국내선      2022-10-21
#
#       VISIT_END_YMD                 ROAD_NM_ADDR                 LOTNO_ADDR  \
# 0        2022-10-21    제주특별자치도 제주시 1100로 2894-49     제주특별자치도 제주시 노형동 291-10
# 1        2022-10-18        제주특별자치도 제주시 오일장중길 100    제주특별자치도 제주시 도두일동 1286-1
# 3        2022-09-17       제주특별자치도 서귀포시 이어도로 1046     제주특별자치도 서귀포시 서호동 128-7
# 4        2022-10-09       제주특별자치도 서귀포시 중문로41번길 8    제주특별자치도 서귀포시 중문동 1588-1
# 6        2022-10-31     제주특별자치도 제주시 조천읍 남조로 1982  제주특별자치도 제주시 조천읍 교래리 385-1
# ...             ...                          ...                        ...
# 62266    2022-09-27  제주특별자치도 제주시 조천읍 조함해안로 217-1  제주특별자치도 제주시 조천읍 신흥리 792-1
# 62267    2022-08-23     제주특별자치도 서귀포시 안덕면 한창로 365  제주특별자치도 서귀포시 안덕면 상창리 2892
# 62269    2022-10-04           제주특별자치도 제주시 노연로 80      제주특별자치도 제주시 연동 263-15
# 62270    2022-09-10        인천 옹진군 덕적면 덕적북로 31-22           인천 옹진군 덕적면 진리 87
# 62271    2022-10-21               서울 강서구 하늘길 112            서울 강서구 공항동 1373
#
#            X_COORD      Y_COORD  ...  TRAVEL_STYL_8 TRAVEL_STATUS_RESIDENCE  \
# 0       126.487556    33.449947  ...            7.0                   서울특별시
# 1       126.477007    33.498441  ...            6.0                    전라북도
# 3       126.522849    33.245022  ...            3.0                     강원도
# 4       126.424303    33.255724  ...            NaN                     NaN
# 6       126.672394    33.451049  ...            7.0                    경상북도
# ...            ...          ...  ...            ...                     ...
# 62266  126.6440146  33.55347531  ...            6.0                     경기도
# 62267  126.3487373  33.29365237  ...            NaN                     NaN
# 62269  126.4885234  33.48527907  ...            3.0                     경기도
# 62270  126.1540897  37.22679959  ...            7.0                   서울특별시
# 62271  126.8028655  37.55894903  ...            4.0                   인천광역시
#
#       TRAVEL_STATUS_DESTINATION TRAVEL_STATUS_ACCOMPANY  \
# 0                            제주         3대 동반 여행(친척 포함)
# 1                            제주             2인 여행(가족 외)
# 3                            제주          3인 이상 여행(가족 외)
# 4                           NaN                     NaN
# 6                            제주                자녀 동반 여행
# ...                         ...                     ...
# 62266                        제주                2인 가족 여행
# 62267                       NaN                     NaN
# 62269                        제주                2인 가족 여행
# 62270                        인천             2인 여행(가족 외)
# 62271                        제주                  나홀로 여행
#
#            TRAVEL_STATUS_YMD  TRAVEL_MOTIVE_1 TRAVEL_MOTIVE_2  \
# 0      2022-10-20~2022-10-24              3.0             7.0
# 1      2022-10-16~2022-10-18              3.0             1.0
# 3      2022-09-16~2022-09-18              1.0             3.0
# 4                        NaN              NaN             NaN
# 6      2022-10-30~2022-11-02              7.0             3.0
# ...                      ...              ...             ...
# 62266  2022-09-26~2022-09-28              2.0             3.0
# 62267                    NaN              NaN             NaN
# 62269  2022-10-01~2022-10-04              1.0             3.0
# 62270  2022-09-09~2022-09-10              1.0             3.0
# 62271  2022-10-21~2022-10-24              2.0             4.0
#
#        TRAVEL_MOTIVE_3  TRAVEL_COMPANIONS_NUM  TRAVEL_MISSION_INT
# 0                 10.0                    3.0                  21
# 1                  7.0                    1.0                  21
# 3                  7.0                    3.0                  11
# 4                  NaN                    NaN                  13
# 6                  2.0                    3.0                   2
# ...                ...                    ...                 ...
# 62266              9.0                    1.0                  26
# 62267              NaN                    NaN                  23
# 62269              2.0                    1.0                   2
# 62270              7.0                    1.0                  24
# 62271              7.0                    0.0                   7
#
# [49738 rows x 68 columns]

# %%
# 전처리 2
df_fil = df_fil[[
    'GENDER', 'AGE_GRP',
    'TRAVEL_STYL_1', 'TRAVEL_STYL_2', 'TRAVEL_STYL_3', 'TRAVEL_STYL_4', 'TRAVEL_STYL_5', 'TRAVEL_STYL_6', 'TRAVEL_STYL_7', 'TRAVEL_STYL_8',
    'TRAVEL_MOTIVE_1',
    'TRAVEL_COMPANIONS_NUM',
    'TRAVEL_MISSION_INT',
    'VISIT_AREA_NM',
    'DGSTFN', # 만족도
]]

df_fil = df_fil.dropna()
df_fil # 14930 rows × 15 columns
# Out:
#       GENDER  AGE_GRP  TRAVEL_STYL_1  TRAVEL_STYL_2  TRAVEL_STYL_3  \
# 0          남     30.0            1.0            4.0            2.0
# 1          남     20.0            4.0            1.0            5.0
# 3          여     50.0            4.0            1.0            2.0
# 6          남     30.0            1.0            1.0            1.0
# 12         여     20.0            5.0            3.0            3.0
# ...      ...      ...            ...            ...            ...
# 62264      여     20.0            1.0            2.0            2.0
# 62266      남     30.0            3.0            3.0            3.0
# 62269      남     40.0            2.0            2.0            5.0
# 62270      여     30.0            1.0            1.0            1.0
# 62271      남     30.0            2.0            2.0            2.0
#
#        TRAVEL_STYL_4  TRAVEL_STYL_5  TRAVEL_STYL_6  TRAVEL_STYL_7  \
# 0                2.0            6.0            2.0            2.0
# 1                1.0            1.0            4.0            1.0
# 3                4.0            3.0            3.0            2.0
# 6                5.0            6.0            3.0            5.0
# 12               3.0            3.0            3.0            3.0
# ...              ...            ...            ...            ...
# 62264            4.0            5.0            2.0            5.0
# 62266            4.0            3.0            3.0            4.0
# 62269            1.0            1.0            3.0            2.0
# 62270            3.0            1.0            1.0            3.0
# 62271            6.0            2.0            3.0            3.0
#
#        TRAVEL_STYL_8  TRAVEL_MOTIVE_1  TRAVEL_COMPANIONS_NUM  \
# 0                7.0              3.0                    3.0
# 1                6.0              3.0                    1.0
# 3                3.0              1.0                    3.0
# 6                7.0              7.0                    3.0
# 12               5.0              1.0                    2.0
# ...              ...              ...                    ...
# 62264            6.0              1.0                    2.0
# 62266            6.0              2.0                    1.0
# 62269            3.0              1.0                    1.0
# 62270            7.0              1.0                    1.0
# 62271            4.0              2.0                    0.0
#
#        TRAVEL_MISSION_INT  VISIT_AREA_NM  DGSTFN
# 0                      21          미스틱3도     5.0
# 1                      21        에스제이렌트카     4.0
# 3                      11           법환식당     5.0
# 6                       2         에코랜드호텔     5.0
# 12                     21      윤스타피자앤파스타     4.0
# ...                   ...            ...     ...
# 62264                  28         함덕촐래밥상     5.0
# 62266                  26     문개항아리 조천본점     5.0
# 62269                   2        메종글래드제주     3.0
# 62270                  24  옹진농협하나로마트 덕적점     5.0
# 62271                   7     김포국제공항 국내선     4.0
#
# [34976 rows x 15 columns]

# %%
# 전처리 3
cat_features_names = [
    'GENDER',
    #'AGE_GRP',
    'TRAVEL_STYL_1', 'TRAVEL_STYL_2', 'TRAVEL_STYL_3', 'TRAVEL_STYL_4', 'TRAVEL_STYL_5', 'TRAVEL_STYL_6', 'TRAVEL_STYL_7', 'TRAVEL_STYL_8',
    'TRAVEL_MOTIVE_1',
    #'TRAVEL_COMPANIONS_NUM',
    'TRAVEL_MISSION_INT',
    'VISIT_AREA_NM',
    #'DGSTFN',
]
df_fil[cat_features_names[1:-1]] = df_fil[cat_features_names[1:-1]].astype(int)
df_fil
# Out:
#       GENDER  AGE_GRP  TRAVEL_STYL_1  TRAVEL_STYL_2  TRAVEL_STYL_3  \
# 0          남     30.0              1              4              2
# 1          남     20.0              4              1              5
# 3          여     50.0              4              1              2
# 6          남     30.0              1              1              1
# 12         여     20.0              5              3              3
# ...      ...      ...            ...            ...            ...
# 62264      여     20.0              1              2              2
# 62266      남     30.0              3              3              3
# 62269      남     40.0              2              2              5
# 62270      여     30.0              1              1              1
# 62271      남     30.0              2              2              2
#
#        TRAVEL_STYL_4  TRAVEL_STYL_5  TRAVEL_STYL_6  TRAVEL_STYL_7  \
# 0                  2              6              2              2
# 1                  1              1              4              1
# 3                  4              3              3              2
# 6                  5              6              3              5
# 12                 3              3              3              3
# ...              ...            ...            ...            ...
# 62264              4              5              2              5
# 62266              4              3              3              4
# 62269              1              1              3              2
# 62270              3              1              1              3
# 62271              6              2              3              3
#
#        TRAVEL_STYL_8  TRAVEL_MOTIVE_1  TRAVEL_COMPANIONS_NUM  \
# 0                  7                3                    3.0
# 1                  6                3                    1.0
# 3                  3                1                    3.0
# 6                  7                7                    3.0
# 12                 5                1                    2.0
# ...              ...              ...                    ...
# 62264              6                1                    2.0
# 62266              6                2                    1.0
# 62269              3                1                    1.0
# 62270              7                1                    1.0
# 62271              4                2                    0.0
#
#        TRAVEL_MISSION_INT  VISIT_AREA_NM  DGSTFN
# 0                      21          미스틱3도     5.0
# 1                      21        에스제이렌트카     4.0
# 3                      11           법환식당     5.0
# 6                       2         에코랜드호텔     5.0
# 12                     21      윤스타피자앤파스타     4.0
# ...                   ...            ...     ...
# 62264                  28         함덕촐래밥상     5.0
# 62266                  26     문개항아리 조천본점     5.0
# 62269                   2        메종글래드제주     3.0
# 62270                  24  옹진농협하나로마트 덕적점     5.0
# 62271                   7     김포국제공항 국내선     4.0
#
# [34976 rows x 15 columns]

# %%
# 데이터셋 분류
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(df_fil, test_size = 0.2, random_state=2023)
print(train_data.shape)
print(test_data.shape)
# Out:
# (27980, 15)
# (6996, 15)

# %%
# !pip install -q catboost

# %%
# Catboost
from catboost import CatBoostRegressor, Pool
train_pool = Pool(train_data.drop(['DGSTFN'], axis=1),# 열방향
                  label = train_data['DGSTFN'],
                  cat_features = cat_features_names)

test_pool = Pool(test_data.drop(['DGSTFN'], axis=1),# 열방향
                 label = test_data['DGSTFN'],
                 cat_features = cat_features_names)

# %%
# !pip install ipywidgets ipython
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: ipython in c:\users\user\anaconda3\envs\tf\lib\site-packages (8.18.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\user\anaconda3\envs\tf\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\user\anaconda3\envs\tf\lib\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\envs\tf\lib\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\envs\tf\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\envs\tf\lib\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\user\anaconda3\envs\tf\lib\site-packages (from ipython) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\envs\tf\lib\site-packages (from ipython) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\envs\tf\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: typing-extensions in c:\users\user\anaconda3\envs\tf\lib\site-packages (from ipython) (4.13.2)
# Requirement already satisfied: exceptiongroup in c:\users\user\anaconda3\envs\tf\lib\site-packages (from ipython) (1.3.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\tf\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\envs\tf\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\user\anaconda3\envs\tf\lib\site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\anaconda3\envs\tf\lib\site-packages (from stack-data->ipython) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\anaconda3\envs\tf\lib\site-packages (from stack-data->ipython) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\user\anaconda3\envs\tf\lib\site-packages (from stack-data->ipython) (0.2.3)
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 11.2 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
#
#    -------------------------- ------------- 2/3 [ipywidgets]
#    ---------------------------------------- 3/3 [ipywidgets]
#
# Successfully installed ipywidgets-8.1.7 jupyterlab_widgets-3.0.15 widgetsnbextension-4.0.14

# %%
# 모델 생성
model = CatBoostRegressor(
    loss_function = 'RMSE', # 평균제곱근오차
    eval_metric='MAE', # 평균오차
    task_type='CPU',
    depth=6,
    learning_rate=0.01,
    n_estimators=2000)

model.fit(
    train_pool,
    eval_set = test_pool,
    verbose=500,
    plot=True )
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.6880129	test: 0.6888884	best: 0.6888884 (0)	total: 176ms	remaining: 5m 52s
# 500:	learn: 0.6001642	test: 0.5856055	best: 0.5856055 (500)	total: 18.1s	remaining: 54.2s
# 1000:	learn: 0.5900576	test: 0.5765765	best: 0.5765765 (1000)	total: 35.8s	remaining: 35.8s
# 1500:	learn: 0.5843254	test: 0.5729654	best: 0.5729654 (1500)	total: 54.3s	remaining: 18.1s
# 1999:	learn: 0.5806152	test: 0.5714111	best: 0.5714097 (1998)	total: 1m 13s	remaining: 0us
#
# bestTest = 0.5714096906
# bestIteration = 1998
#
# Shrink model to first 1999 iterations.

# %%
test_data.iloc[2]
# Out:
# GENDER                        남
# AGE_GRP                    30.0
# TRAVEL_STYL_1                 3
# TRAVEL_STYL_2                 2
# TRAVEL_STYL_3                 3
# TRAVEL_STYL_4                 3
# TRAVEL_STYL_5                 5
# TRAVEL_STYL_6                 4
# TRAVEL_STYL_7                 2
# TRAVEL_STYL_8                 6
# TRAVEL_MOTIVE_1               1
# TRAVEL_COMPANIONS_NUM       1.0
# TRAVEL_MISSION_INT           26
# VISIT_AREA_NM            면수동흑돼지
# DGSTFN                      4.0
# Name: 16995, dtype: object

# %%
# 모델 테스트
model.predict(test_data.iloc[2].drop(['DGSTFN']))
# Out:
# 3.901923806952547

# %%
# 테스트데이터 갯수 확인 (1~5점) # 만족도 지표가 1, 2은 거의 없고
test_data[test_data['DGSTFN'] == 4].index
# Out:
# Index([16995, 11819, 23387, 52002, 59290,   813, 44261, 41157, 31365, 48155,
#        ...
#        32754, 38852,  9652, 17769,  9303, 36888, 60592, 62009, 30415, 52836],
#       dtype='int64', length=2553)

# %%
model.get_feature_importance(prettified=True)
# Out:
#                Feature Id  Importances
# 0           VISIT_AREA_NM    15.376880
# 1      TRAVEL_MISSION_INT    13.225535
# 2           TRAVEL_STYL_8    11.398882
# 3           TRAVEL_STYL_5     8.595120
# 4           TRAVEL_STYL_4     7.546011
# 5           TRAVEL_STYL_2     7.396785
# 6           TRAVEL_STYL_6     7.192551
# 7           TRAVEL_STYL_1     6.538512
# 8           TRAVEL_STYL_7     6.396116
# 9         TRAVEL_MOTIVE_1     6.174996
# 10          TRAVEL_STYL_3     4.766224
# 11                AGE_GRP     4.031785
# 12  TRAVEL_COMPANIONS_NUM     0.980591
# 13                 GENDER     0.380010

# %%
area_names = df_fil[['VISIT_AREA_NM']].drop_duplicates()
area_names
# Out:
#        VISIT_AREA_NM
# 0              미스틱3도
# 1            에스제이렌트카
# 3               법환식당
# 6             에코랜드호텔
# 12         윤스타피자앤파스타
# ...              ...
# 62224            고옥정
# 62227   네스트호텔 쿤스트라운지
# 62230         제이스바버샵
# 62253  블라제리조트 전기차충전소
# 62258            미미슈
#
# [10852 rows x 1 columns]

# %%
traveler = {
    'GENDER':'남',
    'AGE_GRP' : 20.0,
    'TRAVEL_STYL_1' : 6,
    'TRAVEL_STYL_2' : 1,
    'TRAVEL_STYL_3' : 3,
    'TRAVEL_STYL_4' : 4,
    'TRAVEL_STYL_5' : 4,
    'TRAVEL_STYL_6' : 4,
    'TRAVEL_STYL_7' : 5,
    'TRAVEL_STYL_8' : 6,
    'TRAVEL_MOTIVE_1' : 3,
    'TRAVEL_COMPANIONS_NUM' : 4.0,
    'TRAVEL_MISSION_INT' : 5 }
results = pd.DataFrame([], columns=['AREA', 'SCORE'])
for area in area_names['VISIT_AREA_NM']:
  input = list(traveler.values())
  input.append(area)
  score = model.predict(input)
  results = pd.concat([results, pd.DataFrame([[area,score]], columns=['AREA','SCORE'])])
results.sort_values('SCORE', ascending=False)[:10]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18588\473644473.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([[area,score]], columns=['AREA','SCORE'])])
#              AREA     SCORE
# 0              연돈  4.835522
# 0         호텔리젠트마린  4.807158
# 0  한라산국립공원 성판악탐방로  4.798695
# 0            코난해변  4.794082
# 0          미영이네식당  4.793396
# 0            골막식당  4.793053
# 0            일통이반  4.788717
# 0        신창풍차해안도로  4.786366
# 0   빽다방베이커리 제주사수점  4.784804
# 0            보룡제과  4.784492

# %%
results.sort_values('SCORE', ascending=True)[:10]
# Out:
#               AREA     SCORE
# 0           상가리야자숲  3.971304
# 0   금산인삼랜드휴게소 통영방향  3.988701
# 0  쇠소깍전통나룻배 카약체험지점  4.012887
# 0      비스타케이호텔 월드컵  4.013665
# 0              듀포레  4.047217
# 0         아삭아삭순무민박  4.076670
# 0             제스토리  4.126222
# 0             구읍뱃터  4.127030
# 0           더나인스테이  4.136095
# 0        베니키아호텔 제주  4.142618

# %%
# TSY
tsy = pd.read_csv('tc_codeb_코드B.csv')
tsy = tsy[173:179]
tsy
# Out:
#       idx       cd_nm cd_a cd_b cd_memo  cd_memo2 del_flag  order_num  \
# 173  1165  자연 선호 매우선호  TSY    1     NaN       NaN        N        999
# 174  1166  자연 선호 중간선호  TSY    2     NaN       NaN        N        999
# 175  1167  자연 선호 약간선호  TSY    3     NaN       NaN        N        999
# 176  1168          중립  TSY    4     NaN       NaN        N        999
# 177  1169  도시 선호 약간선호  TSY    5     NaN       NaN        N        999
# 178  1170  도시 선호 중간선호  TSY    6     NaN       NaN        N        999
#
#                       ins_dt edit_dt
# 173  2022-09-22 17:34:50.000     NaN
# 174  2022-09-22 17:34:50.000     NaN
# 175  2022-09-22 17:34:50.000     NaN
# 176  2022-09-22 17:34:50.000     NaN
# 177  2022-09-22 17:34:50.000     NaN
# 178  2022-09-22 17:34:50.000     NaN

# %%
# TMT
tmt = pd.read_csv('tc_codeb_코드B.csv')
tmt = tmt[180:190]
tmt
# Out:
#       idx                             cd_nm cd_a cd_b cd_memo  cd_memo2  \
# 180  1172        일상적인 환경 및 역할에서의 탈출, 지루함 탈피  TMT    1     NaN       NaN
# 181  1173     쉴 수 있는 기회, 육체 피로 해결 및 정신적인 휴식  TMT    2     NaN       NaN
# 182  1174             여행 동반자와의 친밀감 및 유대감 증진  TMT    3     NaN       NaN
# 183  1175       진정한 자아 찾기 또는 자신을 되돌아볼 기회 찾기  TMT    4     NaN       NaN
# 184  1176                    SNS 사진 등록 등 과시  TMT    5     NaN       NaN
# 185  1177                    운동, 건강 증진 및 충전  TMT    6     NaN       NaN
# 186  1178                         새로운 경험 추구  TMT    7     NaN       NaN
# 187  1179            역사 탐방, 문화적 경험 등 교육적 동기  TMT    8     NaN       NaN
# 188  1180  특별한 목적(칠순여행, 신혼여행, 수학여행, 인센티브여행)  TMT    9     NaN       NaN
# 189  1181                                기타  TMT   10     NaN       NaN
#
#     del_flag  order_num                   ins_dt edit_dt
# 180        N        999  2022-09-22 17:34:50.000     NaN
# 181        N        999  2022-09-22 17:34:50.000     NaN
# 182        N        999  2022-09-22 17:34:50.000     NaN
# 183        N        999  2022-09-22 17:34:50.000     NaN
# 184        N        999  2022-09-22 17:34:50.000     NaN
# 185        N        999  2022-09-22 17:34:50.000     NaN
# 186        N        999  2022-09-22 17:34:50.000     NaN
# 187        N        999  2022-09-22 17:34:50.000     NaN
# 188        N        999  2022-09-22 17:34:50.000     NaN
# 189        N        999  2022-09-22 17:34:50.000     NaN

# %%
# MIS
mis = pd.read_csv('tc_codeb_코드B.csv')
mis = mis[105:126]
mis
# Out:
#       idx                 cd_nm cd_a cd_b cd_memo  cd_memo2 del_flag  \
# 105  1097                    쇼핑  MIS    1     NaN       NaN        N
# 106  1098  테마파크, 놀이시설, 동/식물원 방문  MIS    2     NaN       NaN        N
# 107  1099             역사 유적지 방문  MIS    3     NaN       NaN        N
# 108  1100                  시티투어  MIS    4     NaN       NaN        N
# 109  1101        야외 스포츠, 레포츠 활동  MIS    5     NaN       NaN        N
# ..    ...                   ...  ...  ...     ...       ...      ...
# 121  1113             신규 여행지 발굴  MIS   24     NaN       NaN        N
# 122  1114            반려동물 동반 여행  MIS   25     NaN       NaN        N
# 123  1115         인플루언서 따라하기 여행  MIS   26     NaN       NaN        N
# 124  1116        친환경 여행(플로깅 여행)  MIS   27     NaN       NaN        N
# 125  1117                 등반 여행  MIS   28     NaN       NaN        N
#
#      order_num                   ins_dt edit_dt
# 105        999  2022-07-27 16:26:52.000     NaN
# 106        999  2022-07-27 16:26:58.000     NaN
# 107        999  2022-07-27 16:27:03.000     NaN
# 108        999  2022-07-27 16:27:08.000     NaN
# 109        999  2022-07-27 16:27:14.000     NaN
# ..         ...                      ...     ...
# 121        999  2022-07-27 16:28:21.000     NaN
# 122        999  2022-07-27 16:28:26.000     NaN
# 123        999  2022-07-27 16:28:34.000     NaN
# 124        999  2022-07-27 16:30:10.000     NaN
# 125        999  2022-07-27 16:30:13.000     NaN
#
# [21 rows x 10 columns]
